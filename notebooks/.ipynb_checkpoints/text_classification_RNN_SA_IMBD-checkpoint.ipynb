# %% [markdown]
# #### REF
# * https://github.com/dmlc/gluon-nlp/blob/master/docs/api/notes/data_api.rst

# %% [markdown]
# ## Data Loading

# %%
import os
import pandas as pd
import numpy as np
import collections
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score, auc
from mxnet import gluon, autograd, nd
from mxnet.gluon import nn, rnn
import gluonnlp as gnlp

import time, re
import multiprocessing as mp
import itertools
from tqdm import tqdm, tqdm_notebook
import mxnet as mx
import spacy
from mxnet.ndarray.linalg import gemm2

os.environ['MXNET_ENGINE_TYPE'] = 'NaiveEngine'
context = mx.gpu()

# %%
max_sentence_length = 100
max_vocab = 10000
batch_size = 64
log_interval = 10

# %% [markdown]
# ### Load Data

# %%
import pickle 
with open('../data/nouns.pkl', 'rb') as f:
    train_dataset_tkn, test_dataset_tkn = pickle.load(f)

# %% [markdown]
# ### Get word embedding

# %%
fasttext_en = gnlp.embedding.create('fasttext', source='wiki.en')

# %%
import itertools
train_seqs = [sample[0] for sample in train_dataset_tkn]
counter = gnlp.data.count_tokens(list(itertools.chain.from_iterable(train_seqs)))
vocab = gnlp.Vocab(counter, max_size=10000)
print(vocab)
# Out:
# Vocab(size=10004, unk="<unk>", reserved="['<pad>', '<bos>', '<eos>']")

# %%
def token_to_idx(x):
    return vocab[x[0]], x[1]

pool = mp.Pool()
train_dataset = pool.map(token_to_idx, train_dataset_tkn)
test_dataset = pool.map(token_to_idx, test_dataset_tkn)
pool.close()
print(train_dataset[0][0][:50])
# Out:
# [0, 161, 672, 106, 5, 6, 145, 22, 1400, 269, 51, 4, 7, 1221, 7, 5, 6, 4127, 60, 6297, 4942, 140, 129, 0, 161, 17, 1669, 296, 476, 7, 1221, 7, 5, 13, 0, 1002, 9063, 4, 5161, 663, 113, 1054, 1221, 21, 0, 4, 0, 442, 4, 600]

# %%
batchify_fn = gnlp.data.batchify.Tuple(gnlp.data.batchify.Pad(axis=0),
                                       gnlp.data.batchify.Stack(), 
                                       gnlp.data.batchify.Stack())

# %%
max_sentence_length = 100

train_dataset_new = []
for i, (x, y) in enumerate(train_dataset):
    if len(x) < max_sentence_length:
        x.extend([0] * ((max_sentence_length) - len(x)))
    else:
        x = x[:max_sentence_length]
    train_dataset_new.append([x,y,i])
    
test_dataset_new = []
for i, (x, y) in enumerate(test_dataset):
    if len(x) < max_sentence_length:
        x.extend([0] * ((max_sentence_length) - len(x)))
    else:
        x = x[:max_sentence_length]
    test_dataset_new.append([x,y,i])

# %%
train_dataloader = gluon.data.DataLoader(dataset=train_dataset_new,
                                         shuffle=True,
                                         batchify_fn=batchify_fn, batch_size = batch_size, 
                                         last_batch = 'discard')
test_dataloader = gluon.data.DataLoader(dataset=test_dataset_new,
                                        shuffle=True,
                                        batchify_fn=batchify_fn, batch_size = batch_size, 
                                        last_batch = 'discard')

# %%
vocab.set_embedding(fasttext_en)
in_vocab_size, out_vocab_size = vocab.embedding.idx_to_vec.shape

# %% [markdown]
# #### Sentence Representation

# %%
class Sentence_Representation(nn.Block):
    def __init__(self, **kwargs):
        super(Sentence_Representation, self).__init__()
        for (k, v) in kwargs.items():
            setattr(self, k, v)
        
        with self.name_scope():
            self.embed = nn.Embedding(self.vocab_size, self.emb_dim)
            self.drop = nn.Dropout(.2)
            self.bi_rnn = rnn.BidirectionalCell(
                 rnn.LSTMCell(hidden_size = self.hidden_dim // 2),  #mx.rnn.LSTMCell doesnot work
                 rnn.LSTMCell(hidden_size = self.hidden_dim // 2)
            )
            self.w_1 = nn.Dense(self.d, use_bias = False)
            self.w_2 = nn.Dense(self.r, use_bias = False)

    def forward(self, x, hidden):
        embeds = self.embed(x) # batch * time step * embedding
        h, _ = self.bi_rnn.unroll(length = embeds.shape[1] \
                                       , inputs = embeds \
                                       , layout = 'NTC' \
                                       , merge_outputs = True)
        # For understanding
        batch_size, time_step, _ = h.shape
        # get self-attention
        _h = h.reshape((-1, self.hidden_dim))
        _w = nd.tanh(self.w_1(_h))
        w = self.w_2(_w)
        _att = w.reshape((-1, time_step, self.r)) # Batch * Timestep * r
        att = nd.softmax(_att, axis = 1)
        x = gemm2(att, h, transpose_a = True)  # h = Batch * Timestep * (2 * hidden_dim), a = Batch * Timestep * r
        return x, att

# %% [markdown]
# #### Classifier

# %%
classifier = nn.Sequential()
classifier.add(nn.Dense(16, activation = 'relu'))
classifier.add(nn.Dense(8, activation = 'relu'))
classifier.add(nn.Dense(1))
classifier.collect_params().initialize(mx.init.Xavier(), ctx = context)

# %% [markdown]
# #### Sentiment analysis classifier

# %%
class SA_SA_Classifier(nn.Block):
    def __init__(self, sen_rep, classifier, context, **kwargs):
        super(SA_SA_Classifier, self).__init__(**kwargs)
        self.context = context
        with self.name_scope():
            self.sen_rep = sen_rep
            self.classifier = classifier
            
    def forward(self, x):
        # Initial hidden state
        hidden = self.sen_rep.bi_rnn.begin_state()

        # sentence representation할 때 hidden의 context가 cpu여서 오류 발생. context를 gpu로 전환
        lstm_out, att = self.sen_rep(x, hidden)
        x = nd.flatten(lstm_out)
        res = self.classifier(x)
        return res, att

# %% [markdown]
# #### Initiate sentiment classifier

# %%
emb_dim = 50 # Emb dim
hidden_dim = 30 # Hidden dim for LSTM

param = {'emb_dim': emb_dim, 'hidden_dim': hidden_dim, 'vocab_size': in_vocab_size, 'd': 10, 'r': 5, 'dropout': .2}
sen_rep = Sentence_Representation(**param)
sen_rep.collect_params().initialize(mx.init.Xavier(), ctx = context)

# %%
sa = SA_SA_Classifier(sen_rep, classifier, context)
loss = gluon.loss.SigmoidBCELoss()
trainer = gluon.Trainer(sa.collect_params(), 'adam', {'learning_rate': 1e-3})

# %%
def evaluate(net, dataIterator, context):
    loss = gluon.loss.SigmoidBCELoss()
    total_L = 0.0
    total_sample_num = 0
    total_correct_num = 0
    start_log_interval_time = time.time()
    for i, (data, label, _) in enumerate(train_dataloader):
        _data = data.as_in_context(context)
        _label = label.as_in_context(context).astype('float32')
        _out, att = net(_data)
        L = loss(_out, _label)
        pred = (_out > 0.5).reshape((-1,))
        total_L += L.sum().asscalar()
        total_sample_num += len(_label)
        total_correct_num += (pred == _label).sum().asscalar()
        if (i + 1) % log_interval == 0:
            print('[Batch {}/{}] elapsed {:.2f} s'.format(
                i + 1, len(dataIterator),
                time.time() - start_log_interval_time))
            start_log_interval_time = time.time()
    avg_L = total_L / float(total_sample_num)
    acc = total_correct_num / float(total_sample_num)
    return avg_L, acc

# %%
n_epoch = 5
for epoch in tqdm_notebook(range(n_epoch), desc = 'epoch'):

    # Epoch training stats
    start_epoch_time = time.time()
    epoch_L = 0.0
    epoch_sent_num = 0
    epoch_wc = 0
    # Log interval training stats
    start_log_interval_time = time.time()
    log_interval_wc = 0
    log_interval_sent_num = 0
    log_interval_L = 0.0
    
    for i, (data, label, _) in enumerate(train_dataloader):
        _data = data.as_in_context(context)
        _label = label.as_in_context(context).astype('float32')
        L = 0
        wc = len(_data)
        log_interval_wc += wc
        epoch_wc += wc
        log_interval_sent_num += _data.shape[1]
        epoch_sent_num += _data.shape[1]
        with autograd.record():
            _out, att = sa(_data)
            pen = gemm2(att, att, transpose_b = True)
            # Penalty
            tmp = nd.dot(att[0], att[0].T) -nd.array(np.identity(att[0].shape[0]), ctx = context)
            pen = nd.sum(nd.multiply(nd.abs(tmp), nd.abs(tmp)))
            L = L + loss(_out, _label).mean().as_in_context(context) + .5 * pen
        L.backward()
        trainer.step(_data.shape[0])
        log_interval_L += L.asscalar()
        epoch_L += L.asscalar()
        if (i + 1) % log_interval == 0:
            tqdm.write('[Epoch {} Batch {}/{}] elapsed {:.2f} s, \
                    avg loss {:.6f}, throughput {:.2f}K wps'.format(
                    epoch, i + 1, len(train_dataloader),
                    time.time() - start_log_interval_time,
                    log_interval_L / log_interval_sent_num,
                    log_interval_wc / 1000 / (time.time() - start_log_interval_time)))
            # Clear log interval training stats
            start_log_interval_time = time.time()
            log_interval_wc = 0
            log_interval_sent_num = 0
            log_interval_L = 0
    end_epoch_time = time.time()
    test_avg_L, test_acc = evaluate(sa, test_dataloader, context)
    tqdm.write('[Epoch {}] train avg loss {:.6f}, valid acc {:.2f}, \
        valid avg loss {:.6f}, throughput {:.2f}K wps'.format(
        epoch, epoch_L / epoch_sent_num,
        test_acc, test_avg_L, epoch_wc / 1000 /
        (end_epoch_time - start_epoch_time)))
# Out:
# HBox(children=(IntProgress(value=0, description='epoch', max=5), HTML(value='')))
# [Epoch 0 Batch 10/390] elapsed 3.60 s,                     avg loss 0.492018, throughput 0.18K wps
# [Epoch 0 Batch 20/390] elapsed 3.56 s,                     avg loss 0.491875, throughput 0.18K wps
# [Epoch 0 Batch 30/390] elapsed 3.56 s,                     avg loss 0.492303, throughput 0.18K wps
# [Epoch 0 Batch 40/390] elapsed 3.55 s,                     avg loss 0.492200, throughput 0.18K wps
# [Epoch 0 Batch 50/390] elapsed 3.55 s,                     avg loss 0.490423, throughput 0.18K wps
# [Epoch 0 Batch 60/390] elapsed 3.56 s,                     avg loss 0.490704, throughput 0.18K wps
# [Epoch 0 Batch 70/390] elapsed 3.55 s,                     avg loss 0.492533, throughput 0.18K wps
# [Epoch 0 Batch 80/390] elapsed 3.55 s,                     avg loss 0.492351, throughput 0.18K wps
# [Epoch 0 Batch 90/390] elapsed 3.55 s,                     avg loss 0.490503, throughput 0.18K wps
# [Batch 380/390] elapsed 1.87 s
# [Batch 390/390] elapsed 1.87 s
# [Epoch 3] train avg loss 0.485825, valid acc 0.84,         valid avg loss 0.353861, throughput 0.18K wps
# [Epoch 4 Batch 10/390] elapsed 3.58 s,                     avg loss 0.485978, throughput 0.18K wps
# [Epoch 4 Batch 20/390] elapsed 3.55 s,                     avg loss 0.486635, throughput 0.18K wps
# [Epoch 4 Batch 30/390] elapsed 3.55 s,                     avg loss 0.485499, throughput 0.18K wps
# [Epoch 4 Batch 40/390] elapsed 3.56 s,                     avg loss 0.484313, throughput 0.18K wps
# [Epoch 4 Batch 50/390] elapsed 3.55 s,                     avg loss 0.486176, throughput 0.18K wps
# [Epoch 4 Batch 60/390] elapsed 3.55 s,                     avg loss 0.484287, throughput 0.18K wps
# [Epoch 4 Batch 70/390] elapsed 3.55 s,                     avg loss 0.484060, throughput 0.18K wps
# [Epoch 4 Batch 80/390] elapsed 3.55 s,                     avg loss 0.484753, throughput 0.18K wps
# [Epoch 4 Batch 90/390] elapsed 3.55 s,                     avg loss 0.484474, throughput 0.18K wps
# [Epoch 4 Batch 100/390] elapsed 3.56 s,                     avg loss 0.485541, throughput 0.18K wps
# [Epoch 4 Batch 110/390] elapsed 3.55 s,                     avg loss 0.485859, throughput 0.18K wps
# [Epoch 4 Batch 120/390] elapsed 3.56 s,                     avg loss 0.483555, throughput 0.18K wps
# [Epoch 4 Batch 130/390] elapsed 3.56 s,                     avg loss 0.486138, throughput 0.18K wps
# [Epoch 4 Batch 140/390] elapsed 3.55 s,                     avg loss 0.485482, throughput 0.18K wps
# [Epoch 4 Batch 150/390] elapsed 3.55 s,                     avg loss 0.483147, throughput 0.18K wps
# [Epoch 4 Batch 160/390] elapsed 3.55 s,                     avg loss 0.484489, throughput 0.18K wps
# [Epoch 4 Batch 170/390] elapsed 3.56 s,                     avg loss 0.483533, throughput 0.18K wps
# [Epoch 4 Batch 180/390] elapsed 3.54 s,                     avg loss 0.485395, throughput 0.18K wps
# [Epoch 4 Batch 190/390] elapsed 3.55 s,                     avg loss 0.484999, throughput 0.18K wps
# [Batch 260/390] elapsed 1.87 s
# [Batch 270/390] elapsed 1.87 s
# [Batch 280/390] elapsed 1.87 s
# [Batch 290/390] elapsed 1.87 s
# [Batch 300/390] elapsed 1.87 s
# [Batch 310/390] elapsed 1.87 s
# [Batch 320/390] elapsed 1.87 s
# [Batch 330/390] elapsed 1.87 s
# [Batch 340/390] elapsed 1.87 s
# [Batch 350/390] elapsed 1.87 s
# [Batch 360/390] elapsed 1.87 s
# [Batch 370/390] elapsed 1.87 s
# [Batch 380/390] elapsed 1.88 s
# [Batch 390/390] elapsed 1.87 s
# [Epoch 4] train avg loss 0.484794, valid acc 0.82,         valid avg loss 0.366709, throughput 0.18K wps

# %% [markdown]
# ### Prediction

# %%
def get_pred(net, iterator):
    pred_sa = []
    label_sa = []
    va_text = []
    for i, (data, label, _) in enumerate(train_dataloader):
        if i % 100 == 0:
            print('i = {}'.format(i))
        _data = data.as_in_context(context)
        _label = label.as_in_context(context).astype('float32')
        _out, _ = net(_data)
        L = loss(_out, _label)
        pred = (nd.sigmoid(_out) > 0.5).reshape((-1,))
        pred_sa.extend(pred.asnumpy())
        label_sa.extend(label.asnumpy())
        va_text.extend([' '.join([vocab.idx_to_token[np.int(x)] for x in y.asnumpy() if vocab.idx_to_token[np.int(x)] is not 'PAD']) for y in data])
    pred_sa_pd = pd.DataFrame(pred_sa, columns  = ['pred_sa'])
    label_pd = pd.DataFrame(label_sa, columns = ['label'])
    text_pd = pd.DataFrame(va_text, columns = ['text'])
    res = pd.concat([text_pd, pred_sa_pd, label_pd], axis = 1)
    return res

# %% [markdown]
# ## Classification results

# %%
result = get_pred(sa, test_dataset_new)
# Out:
# i = 0
# i = 100
# i = 200
# i = 300

# %%
result[result.pred_sa != result.label].shape
# Out:
# (3912, 3)

# %%
result[result.pred_sa != result.label].head(10)
# Out:
#                                                  text  pred_sa  label
# 15  the good western mann <unk> ensemble hollywood...      1.0      0
# 16  earlier today -PRON- get argument people compl...      1.0      0
# 27  this pretty ok film ... yes part lame exceptio...      0.0      1
# 28  this movie great . if enjoy watch b - class mo...      0.0      1
# 32  for have hear ( see <unk> ) , cracker brillian...      1.0      0
# 43  this weird movie archaeologist study culture a...      0.0      1
# 46  while premise film pretty lame ( ollie <unk> "...      0.0      1
# 55  -PRON- <unk> boy pass beginning series small b...      1.0      0
# 61  a routine mystery / thriller concern killer lu...      1.0      0
# 64  first -PRON- admit batman : the animate series...      1.0      0

# %%
result[result.pred_sa != result.label]['text'].iloc[1]
# Out:
# 'earlier today -PRON- get argument people complain modern film -PRON- encounter curious statement : " character development new movie not nearly good interesting . " depend <unk> ) question , attribute number thing , generic special effect plot - drive hollywood garbage like war of the worlds , case - - , uninteresting attempt social commentary desperate struggle " art " cinema , be movie like dog days <unk> /><br />i normally high tolerance movie , matter dull pointless -PRON- find ( range good , long one like <unk> <unk> <unk> , one -PRON- have consider painful sit la alpha'

# %% [markdown]
# ## Visualize attention

# %%
te_origin = [x[2] for x in test_dataset_tkn]
def plot_attention(net, n_samples = 10, mean = False):
    from matplotlib import pyplot as plt
    import seaborn as sns
    sns.set()
    idx = np.random.choice(np.arange(len(test_dataset_new)), size = n_samples, replace = False)
    _dat = [test_dataset_new[i][0] for i in idx]
    
    w_idx = []
    word = [[vocab.idx_to_token[x] for x in y] for y in _dat]
    original_txt = [va_origin[i] for i in idx]
    out, att = net(nd.array(_dat, ctx = context)) 
    print('attention shape = {}'.format(att.shape))
    _a = []
    _w = []
    for x, y, z in zip(word, att, original_txt):
        _idx = [i for i, _x in enumerate(x) if _x is not 'PAD']
        _w.append(np.array([x[i] for i in _idx]))
        _a.append(np.array([y[i].asnumpy() for i in _idx]))
        
    _dat = [test_dataset_new[i][1] for i in idx]
    _pred = (nd.sigmoid(out) > .5).asnumpy()
    
    fig, axes = plt.subplots(np.int(np.ceil(n_samples / 4)), 4, sharex = False, sharey = True)
    plt.subplots_adjust(hspace=1)
    if mean == True:
        fig.set_size_inches(20, 4)
        plt.subplots_adjust(hspace=5)
    else:
        fig.set_size_inches(20, 20)
        plt.subplots_adjust(hspace=1)
    cbar_ax = fig.add_axes([.91, .3, .04, .4])
    
    
    
    for i in range(n_samples):
        if mean == True:
            _data = nd.softmax(nd.array(np.mean(_a[i], axis = 1))).asnumpy()
            sns.heatmap(pd.DataFrame(_data, index = _w[i]).T, ax = axes.flat[i], cmap = 'RdYlGn', linewidths = .3, cbar_ax = cbar_ax)
        else:
            sns.heatmap(pd.DataFrame(_a[i], index = _w[i]).T, ax = axes.flat[i], cmap = 'RdYlGn', linewidths = .3, cbar_ax = cbar_ax)
        axes.flat[i].set_title('Label: {}, Pred: {}'.format(_label[i], np.int(_pred[i])))

# %%
# https://stackoverflow.com/questions/49899823/changing-width-of-heatmap-in-seaborn-to-compensate-for-font-size-reduction
def plot_neuron_heatmap(text, values, title, n_limit=80, savename='fig1.png',
                        cell_height=0.325, cell_width=0.15, dpi=100):
    from matplotlib import pyplot as plt
    import seaborn as sns
    text = text.replace('\n', '\\n')
    text = np.array(list(text + ' ' * (-len(text) % n_limit)))
    if len(values) > text.size:
        values = np.array(values[:text.size])
    else:
        t = values
        values = np.zeros(text.shape, dtype=np.float32)
        values[:len(t)] = t
    text = text.reshape(-1, n_limit)
    values = values.reshape(-1, n_limit)
    plt.figure(figsize=(cell_width * n_limit, cell_height * len(text)))
    hmap = sns.heatmap(values, annot=text, fmt='', cmap='RdYlGn', xticklabels=False, yticklabels=False, cbar=False)
    plt.subplots_adjust()
    plt.title(title)
    plt.savefig(savename, dpi=dpi)

# %%
import spacy
nlp = spacy.load('en')

# %%
def draw_sentence(_idx):
    # Get data from valid set for _idx
    _dat = [test_dataset_new[i][0] for i in _idx]

    w_idx = []
    word = [[vocab.idx_to_token[x] for x in y] for y in _dat]
    original_txt = [te_origin[i][0] for i in _idx]
    out, att = sa(nd.array(_dat, ctx = context)) 
    _a = []
    _w = []
    for x, y, z in zip(word, att, original_txt):
        _ix = [i for i, _x in enumerate(x) if _x is not 'PAD']
        _w.append(np.array([x[i] for i in _ix]))
        _a.append(np.array([y[i].asnumpy() for i in _ix]))

    _label = [test_dataset_new[i][1] for i in _idx]
    _pred = (nd.sigmoid(out) > .5).asnumpy()

    for i, _ix in enumerate(_idx):
        att_score = [] 
        _b = nd.softmax(nd.array(np.mean(_a[i], axis = 1))).asnumpy()
        for x in original_txt[i].split(' '):
            _x_lem = [token.lemma_ for token in nlp(x) if token.is_alpha]
            if len(_x_lem) > 0:
                x_lemma = [token.lemma_ for token in nlp(x) if token.is_alpha][0]
            else:
                x_lemma = ''
            if x_lemma in _w[i]:
                idx = np.argmax(x_lemma == _w[i])
                tmp = [_b[idx]] * len(x)
            else:
                idx = -1
                tmp = [1/len(_w[i])] * len(x)
            tmp.extend([1/len(_w[i])])
            att_score.extend(tmp)
        plot_neuron_heatmap(original_txt[i], att_score[:-1] \
                          , 'Label: {}, Pred: {}'.format(_label[i], np.int(_pred[i])) \
                          , n_limit= len(att_score[:-1]))

# %%
draw_sentence(np.arange(3010, 3020))

# %%
plot_attention(sa, n_samples = 12, mean = True)
# Out:
# attention shape = (12, 20, 5)
